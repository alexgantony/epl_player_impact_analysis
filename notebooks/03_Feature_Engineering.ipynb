# %%
import numpy as np
import pandas as pd

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from config.paths import PROCESSED_DATA_DIR

# %%
df = pd.read_csv(Path(PROCESSED_DATA_DIR / "final_pl_2025_26_nominees_stats.csv"), index_col="playerId")
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#           bigChancesMissed  totalShots  goalConversionPercentage  \
# playerId
# 288205                   8          85                     10.59
# 581310                   0           0                      0.00
# 839956                  30         126                     21.43
# 856714                   3          40                     10.00
# 865912                  10          83                     18.07
#
#           interceptions  clearances  errorLeadToGoal  outfielderBlocks  \
# playerId
# 288205               20          42                0                 5
# 581310                1          37                1                 0
# 839956                5          42                0                 1
# 856714               37          78                1                12
# 865912               13          32                1                 3
#
#           bigChancesCreated  accuratePasses  keyPasses  ...  \
# playerId                                                ...
# 288205                   33            1639        137  ...
# 581310                    0             707          3  ...
# 839956                    9             252         25  ...
# 856714                   17            1865         64  ...
# 865912                    5             980         49  ...
#
#           savesMadeOutsideBox  savesMadeInsideBox  squadMinutesShare%  \
# playerId
# 288205                    NaN                 NaN                89.6
# 581310                   15.0                44.0                97.4
# 839956                    NaN                 NaN                86.3
# 856714                    NaN                 NaN                90.5
# 865912                    NaN                 NaN                90.6
#
#           teamGoalDiffPer90  teamOnOffImpactPer90  tacklesWon  touches  \
# playerId
# 288205                 0.59                  0.84          35     2648
# 581310                 1.16                  1.16           1     1436
# 839956                 1.13                  0.16           7      779
# 856714                 1.08                 -0.86          33     2760
# 865912                -0.09                 -0.09          16     1738
#
#           touchesInOppBox  shotsBlocked  ballRecoveries
# playerId
# 288205                 91            30             167
# 581310                  0             0             305
# 839956                213            24              41
# 856714                 55            13             180
# 865912                127            24             110
#
# [5 rows x 60 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# bigChancesMissed
# totalShots
# goalConversionPercentage
# interceptions
# clearances
# errorLeadToGoal
# outfielderBlocks
# bigChancesCreated
# accuratePasses
# keyPasses
# saves
# cleanSheet
# penaltySave
# savedShotsFromInsideTheBox
# runsOut
# goals
# expectedGoals
# successfulDribbles
# tackles
# assists
# accuratePassesPercentage
# sofascoreRating
# name
# teamName
# potm_wins
# position
# matchesPlayed
# matchesStarted
# minutesPlayed
# nonPenaltyGoals
# expectedAssists
# teamPosition
# teamPoints
# teamGoalsScored
# teamGoalsConceded
# chancesCreated
# finalThirdPassesSuccessful
# accurateFinalThirdPassPerc
# possessionWon
# groundDuelsWon%
# aerialDuelsWon%
# yellows
# reds
# fouls
# penaltyConceded
# progressiveCarries
# goalsConceded
# savesMade
# savePerc
# goalsPrevented
# savesMadeOutsideBox
# savesMadeInsideBox
# squadMinutesShare%
# teamGoalDiffPer90
# teamOnOffImpactPer90
# tacklesWon
# touches
# touchesInOppBox
# shotsBlocked
# ballRecoveries
